# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import SGD, Adam
from keras.utils import to_categorical

# %%
def load_data():
  x_train = list()
  y_train = list()
  tmp = np.ones((2999,))
  for i in range(10):
    x_train.extend(np.loadtxt("train/"+str(i)+".mfcc"))
    y_train.extend(tmp * i)
  y_train = to_categorical(y_train, num_classes=10)
  return np.array(x_train), y_train

# %%
x_train, y_train = load_data()

# %%
x_train.shape
# Out:
# (29990, 39)

# %%
y_train.shape
# Out:
# (29990, 10)

# %%
model = Sequential()

# %%
model.add(Dense(512, input_dim=39, activation='relu'))

# %%
model.add(Dense(2048, activation='relu'))
model.add(Dense(2048, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %%
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)

# %%
model.compile(loss='binary_crossentropy', optimizer=sgd, metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=10, batch_size=512)
# Out:
# Epoch 1/10
# 29990/29990 [==============================] - 20s 652us/step - loss: 0.2690 - acc: 0.9067
# Epoch 2/10
# 29990/29990 [==============================] - 20s 669us/step - loss: 0.2290 - acc: 0.9167
# Epoch 3/10
# 29990/29990 [==============================] - 20s 662us/step - loss: 0.2152 - acc: 0.9214
# Epoch 4/10
# 29990/29990 [==============================] - 20s 661us/step - loss: 0.2061 - acc: 0.9244
# Epoch 5/10
# 29990/29990 [==============================] - 20s 664us/step - loss: 0.1992 - acc: 0.9265
# Epoch 6/10
# 29990/29990 [==============================] - 20s 664us/step - loss: 0.1935 - acc: 0.9286
# Epoch 7/10
# 29990/29990 [==============================] - 20s 664us/step - loss: 0.1887 - acc: 0.9300
# Epoch 8/10
# 29990/29990 [==============================] - 20s 660us/step - loss: 0.1843 - acc: 0.9317
# Epoch 9/10
# 29990/29990 [==============================] - 20s 664us/step - loss: 0.1805 - acc: 0.9330
# Epoch 10/10
# 29990/29990 [==============================] - 20s 663us/step - loss: 0.1768 - acc: 0.9345

# %%
model.evaluate(x_train, y_train)
# Out:
# 29990/29990 [==============================] - 12s 408us/step
# [0.17345157625795246, 0.9359253024450737]

# %%
def load_data_test():
  x_train = list()
  y_train = list()
  tmp = np.ones((100,))
  for i in range(10):
    x_train.extend(np.loadtxt("test/"+str(i)+".mfcc"))
    y_train.extend(tmp * i)
  y_train = to_categorical(y_train, num_classes=10)
  return np.array(x_train), y_train

# %%
x_test, y_test = load_data_test()

# %%
model.evaluate(x_test, y_test)
# Out:
# 1000/1000 [==============================] - 0s 420us/step
# [0.2481941672563553, 0.911299979686737]
